# %% [markdown]
# First we are going to create class named Node which will create Node for us

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

# %% [markdown]
# Here we will create a class named Linked_list in which we will perform functionality of linked list like treverse, delete a node, add a new node etc...

# %%
class Linked_list:
    def __init__(self):
    #Firstly initializing head value to Null
        self.head=None
    
    #In this function we will treverse in linked list  
    def treverse(self):
        if self.head is None:
            print('Linked list is empty')
            return
        
        print_node=self.head
        while print_node is not None:
            print(print_node.data)
            print_node=print_node.next
            
    #In this function we will add new Node it the begining of head
    def insert_at_head(self, data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
        
    #In this function we will add new node at the end of linked list
    def insert_at_end(self,data):
        new_node=Node(data)
        if self.head is None:
            print('Linked list is empty so value inserted at head')
            self.head=new_node
            return 
        
        temp_node=self.head
        while new_node_1.next is not None:
            temp_node=temp_node.next
        temp_node.next=new_node
        
    #In this function we will add new node after the value we will provide
    def insert_after_value(self,data,value):
        new_node = Node(data)
        if self.head is None:
            print('Linked list is empty so value inserted at head')
            self.head=new_node
            return 
        
        temp_node = self.head
        while temp_node is not None:
            if temp_node.data==value:
                break
            temp_node = temp_node.next
            
        if temp_node is None:
            print("Values not in the linked list")
            return
        new_node.next = temp_node.next
        temp_node.next = new_node
        
    #In this function we will add values it specific index
    def insert_after_index(self,data,index):
        new_node = Node(data)
        if self.head is None:
            print('Linked list is empty so values inserted at head')
            self.head=new_node
            return 
        
        count=0
        new_head = self.head
        while new_head is not None:
            if count==index:
                break
            count+=1
            new_head = new_head.next
            
        if new_head is None:
            print("Index is exceeding")
            return
        new_node.next = new_head.next
        new_head.next = new_node
        
    #In this function we will search value in linked list
    def search_value(self,value):
        new_node=self.head
        if self.head is None:
            print("Linekd lis is empty")
            return
        
        while new_node is not None:
            if new_node.data==value:
                print('value found')
                break
            new_node=new_node.next
            print('Not found')
            
    # In this function we will delete node from head
    def head_delete(self):
        if self.head is None:
            return 
        self.head=self.head.next
     
    # In this function we will delete last node from Linked list
    def end_delete(self):
        if self.head is None:
            return 
        if self.head.next == None:
            self.head = None
            return
        new_node=self.head
        while new_node.next.next is not None:
            new_node=new_node.next
        new_node.next=None
        
    # In this function we will delete node by value
    def delete_by_value(self,value):
        if self.head is None:
            return 
        if self.head.data==value:
            self.head=self.head.next
            return 
        new_node=self.head
        while new_node.next is not None:
            if new_node.next.data==value:
                break
            new_node=new_node.next
        if new_node.next is None:
            print("Value not found")
            return
        new_node.next=new_node.next.next
    
    #In this function we will reverse linked list
    def reverse_linked_list(self):
        rev = None
        new_node = self.head
        while new_node is not None:
            nex = new_node.next
            new_node.next = rev
            rev = new_node
            new_node = nex
        self.head = rev
        
    #In this function we will count number of nodes
    def count_node(self):
        new_node=self.head
        count=0
        while new_node is not None:
            count+=1
            new_node=new_node.next
        return count
        
    #This function return the head
    def return_head(self):
        return self.head
